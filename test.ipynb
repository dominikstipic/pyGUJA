# %%
import model
import glob
import os

def file_walker_leveled(path):
    paths = glob.glob(f'{path}/*')
    result = []
    for p in paths:
        if os.path.isfile(p):
            result.append(p)
    return result

gen = file_walker_leveled("/home/doms/Desktop")

len(gen)
# Out:
# 70

# %%
import sys
import matplotlib.pyplot as plt
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QVBoxLayout
from PyQt5.QtGui import QImage, QPixmap

class MatplotlibWidget(QWidget):
    def __init__(self):
        super().__init__()
        self.fig, self.ax = plt.subplots()
        self.ax.plot([1, 2, 3, 4], [10, 20, 25, 30]) 

        width, height = self.canvas.get_width_height()
        image = self.canvas.tostring_rgb()
        qimage = QImage(image, width, height, QImage.Format_RGB888)
        pixmap = QPixmap.fromImage(qimage)
        label = QLabel(self)
        label.setPixmap(pixmap)

        layout = QVBoxLayout()
        layout.addWidget(label)
        self.setLayout(layout)

if __name__ == '__main__':
    app = QApplication(sys.argv)
    widget = MatplotlibWidget()
    widget.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 3
#       1 import sys
#       2 import matplotlib.pyplot as plt
# ----> 3 from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QVBoxLayout
#       4 from PyQt5.QtGui import QImage, QPixmap
#       6 class MatplotlibWidget(QWidget):
#
# ModuleNotFoundError: No module named 'PyQt5'

# %%
def create_bar(xs, ys, title="Analysis"):
    fig, ax = plt.subplots()
    bars = plt.bar(xs, ys)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)
    plt.title(title)
    plt.xticks(rotation=90)
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}', 
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset  

                    textcoords="offset points",
                    ha='center', va='bottom')
    plt.savefig('data.png') 


create_bar(["MS", "IP", "IS"], [83, 10, 10])

# %%
def file_walker_leveled(path):
    paths = glob.glob(f'{path}/*')
    result = []
    for p in paths:
        if os.path.isfile(p):
            result.append(p)
    return result


def create_bar(xs, ys, title="Analysis"):
    _, ax = plt.subplots()
    bars = plt.bar(xs, ys)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)
    plt.title(title)
    plt.xticks(rotation=90)
    plt.savefig("data.png")
    for bar in bars:
        height = round(bar.get_height(), 1)
        ax.annotate(f'{height}', 
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), 
                    textcoords="offset points",
                    ha='center', va='bottom')
    plt.savefig('data.png')


from pathlib import Path

def file_size(file):
    absolute_path = Path(file).resolve()
    return os.path.getsize(absolute_path) / 1000

def get_file_encoded_names(f):
    ns = f.split()
    ns = [n[0].lower() for n in ns]
    return "".join(ns)

fs = file_walker_leveled("/home/doms/Desktop/FOO")
file_names = [fs.split("/")[-1] for fs in fs]
file_sizes = [file_size(f) for f in fs]
        
create_bar(file_names, file_sizes)

# %%
def get_file_encoded_names(f):
    ns = f.split()
    ns = [n[0].lower() for n in ns]

    if "." in f:
        pref, suf = f.split(".")
        name = f"{"".join(ns)}.{suf}"
    else:
        name = f"{"".join(ns)}"
    return name 


get_file_encoded_names("asd asdasd.pdf")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[27], line 13
#       9         name = f"{"".join(ns)}"
#      10     return name
# ---> 13 get_file_encoded_names("asd asdasd.pdf")
#
# Cell In[27], line 2, in get_file_encoded_names(f)
#       1 def get_file_encoded_names(f):
# ----> 2     ns = pref.split()
#       3     ns = [n[0].lower() for n in ns]
#       5     if "." in f:
#
# UnboundLocalError: cannot access local variable 'pref' where it is not associated with a value
